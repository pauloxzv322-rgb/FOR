# %% [markdown]
# <a href="https://colab.research.google.com/github/pauloxzv322-rgb/FOR/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for venda in lista_vendas:
  bonus = 0
  if venda >= meta:
    bonus = venda * percentual_extra

    if venda >= 2000 :
      bonus = bonus + bonus_extra
  print(f"Venda: {venda} -> bonus : R${bonus}")
# Out:
# Venda: 100 -> bonus : R$0
# Venda: 500 -> bonus : R$0
# Venda: 800 -> bonus : R$0
# Venda: 1500 -> bonus : R$150.0
# Venda: 2000 -> bonus : R$250.0
# Venda: 1300 -> bonus : R$130.0

# %% [markdown]
# Atividade 05

# %%
lista_vendas = [1000,500,800,1500,2000,2300]
meta = 1200
percentual_extra = 0.1
bonus_extra = 50

for venda in lista_vendas:
    bonus = 0

    if venda >= meta:
        bonus = venda * percentual_extra
        bonus = bonus + bonus_extra

        if venda >= 2000 :
          bonus = bonus + bonus_extra
          bonus +- bonus_extra
    print(f"Venda: {venda} -> bonus : R${bonus}")
# Out:
# Venda: 1000 -> bonus : R$0
# Venda: 500 -> bonus : R$0
# Venda: 800 -> bonus : R$0
# Venda: 1500 -> bonus : R$200.0
# Venda: 2000 -> bonus : R$300.0
# Venda: 2300 -> bonus : R$330.0

# %% [markdown]
# Atividade 06

# %%
lista_vendas = [1000,500,800,1500,2000,2300]
maior_vendas = lista_vendas[0] # 1000
for venda in lista_vendas:
    if venda > maior_vendas:
        maior_vendas = venda #2300
print("Maior venda: ", maior_vendas)
# Out:
# Maior venda:  2300
